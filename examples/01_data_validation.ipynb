# %% [markdown]
# # Phase 1 — Cyclic Hexapeptide Data Validation
#
# This notebook documents the analysis steps for validating the Phase 1 dataset. Execute the cells *after* generating a dataset with either the MD or Monte Carlo scripts.

# %% [markdown]
# ## 1. Configure paths
# Update the paths below to match the location of your generated dataset.

# %%
from pathlib import Path
dataset_path = Path('../data/cyclo_ala6_md.npy')  # or cyclo_ala6_mc.npy
results_dir = Path('../results/phase1')
results_dir.mkdir(parents=True, exist_ok=True)
dataset_path

# %% [markdown]
# ## 2. Run the validation pipeline
# This mirrors `scripts/phase1/validate_dataset.py`. Feel free to call the script directly instead.

# %%
import numpy as np
from scripts.phase1.validate_dataset import validate_dataset

validate_dataset(dataset_path, results_dir)

# %% [markdown]
# ## 3. Inspect outputs
# Once the script finishes, the figures below can be embedded into the paper.
